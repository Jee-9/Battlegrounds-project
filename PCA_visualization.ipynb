# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('user_map_group.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index                                  playerId  \
# 0           0      0  account.0054db2c9b894940a9d9a4d389749ef2
# 1           1      1  account.0054db2c9b894940a9d9a4d389749ef2
# 2           2      2  account.0054db2c9b894940a9d9a4d389749ef2
# 3           3      3  account.0054db2c9b894940a9d9a4d389749ef2
# 4           4      4  account.0054db2c9b894940a9d9a4d389749ef2
#
#           mapName  DBNOs  assists  boosts  damageDealt  headshotKills  heals  \
# 0     Baltic_Main    0.0      0.0     2.0   127.198166            0.0    2.0
# 1     Desert_Main    8.0      0.0     0.0   800.000000            0.0    0.0
# 2  DihorOtok_Main    6.5      1.5     2.0   787.495975            0.5    1.5
# 3      Range_Main    0.0      0.0     0.0     0.000000            0.0    0.0
# 4     Savage_Main    1.0      0.0     3.0  2989.488300            4.0    0.0
#
#    ...  revives  rideDistance  roadKills  swimDistance  teamKills  \
# ...

# %%
del data['index']

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#                                    playerId         mapName  DBNOs  assists  \
# 0  account.0054db2c9b894940a9d9a4d389749ef2     Baltic_Main    0.0      0.0
# 1  account.0054db2c9b894940a9d9a4d389749ef2     Desert_Main    8.0      0.0
# 2  account.0054db2c9b894940a9d9a4d389749ef2  DihorOtok_Main    6.5      1.5
# 3  account.0054db2c9b894940a9d9a4d389749ef2      Range_Main    0.0      0.0
# 4  account.0054db2c9b894940a9d9a4d389749ef2     Savage_Main    1.0      0.0
#
#    boosts  damageDealt  headshotKills  heals  killPlace  killStreaks  ...  \
# 0     2.0   127.198166            0.0    2.0       47.0          0.0  ...
# 1     0.0   800.000000            0.0    0.0        1.0          1.0  ...
# 2     2.0   787.495975            0.5    1.5        3.0          1.5  ...
# 3     0.0     0.000000            0.0    0.0        5.0          0.0  ...
# 4     3.0  2989.488300            4.0    0.0        9.0          3.0  ...
#
# ...

# %%
data['mapName'].value_counts()
# Out:
# Desert_Main        477
# Baltic_Main        471
# Savage_Main        432
# DihorOtok_Main     417
# Tiger_Main         329
# Range_Main         297
# Chimera_Main        54
# Summerland_Main     39
# Name: mapName, dtype: int64

# %%
df.head()
# Out:
#                                     playerId      mapName  DBNOs  assists  \
# 1   account.0054db2c9b894940a9d9a4d389749ef2  Desert_Main    8.0      0.0
# 8   account.00574808b15f4e2ebf2b88a3f9de7dcd  Desert_Main    1.0      2.5
# 14  account.008fa9bf6dfb4c47a5db9f7effca8ba5  Desert_Main    2.0      1.0
# 21  account.0161437dfa21482297ce65c5bd9ff780  Desert_Main    1.5      1.0
# 26  account.0277f1f40b884ebf89b487f40963afec  Desert_Main    4.0      2.0
#
#     boosts  damageDealt  headshotKills  heals  killPlace  killStreaks  ...  \
# 1      0.0   800.000000            0.0    0.0        1.0          1.0  ...
# 8      6.0   330.987430            0.0    2.5       20.0          1.0  ...
# 14     8.0   373.573300            0.0    3.0       13.0          1.0  ...
# 21     7.0   376.831485            0.5    2.0        9.5          1.0  ...
# 26     6.0   773.507450            1.0    4.0        8.0          2.0  ...
#
# ...

# %%
df['playerId'].duplicated().sum()
# Out:
# 0

# %%
#1.
df["movement_w_mean"] = 0*df["swimDistance"] + 0.78*df["walkDistance"] + 0.22*df["vehicleDestroys"]

#2.
df["kill_over_winPlae"] = round(df["killPlace"]/df["winPlace"], 4)

#3.
df["kill_over_timeSurvived"] = round(df["kills"]/df["timeSurvived"], 4)

# %%
data_pca
# Out:
# array([[-3.77782375e+03,  2.29711965e+03,  5.92035942e+02],
#        [-2.96642337e+02,  4.09204814e+02, -1.42093433e+02],
#        [ 6.40309972e+02,  2.62248830e+02, -7.29471294e+01],
#        ...,
#        [-3.26088371e+02,  2.71093794e+02, -6.08626949e+00],
#        [-1.31876230e+03, -2.40250357e+02,  1.03450770e+02],
#        [ 8.63065978e+01, -1.45836973e+02, -1.33773571e+00]])

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components = 3)
data_pca = pca.fit_transform(train)

# %%
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(data_pca[:, 0], data_pca[:, 1], data_pca[:, 2], s = 60, edgecolors = 'white')
plt.show()

# %%
train = df.drop(columns = ["playerId", "mapName"])

# %% [markdown]
# ### Affinity Propagation

# %%
from sklearn.cluster import AffinityPropagation
from sklearn.metrics import *

# %%
centers = [[1,1], [-1, -1], [1, -1]]

# %%
model = AffinityPropagation(preference = -50).fit(train)
# Out:
# C:\Users\TFG5076XG\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:148: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(

# %%
cluster_centers_indices = model.cluster_centers_indices_
labels = model.labels_
n_clusters_ = len(cluster_centers_indices)

# %%
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 477
