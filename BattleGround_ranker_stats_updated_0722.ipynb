# %%
import requests 
import json
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup 
import time
import csv

#정보담을 리스트(랭커아이디, 매치아이디)

# top_3=[]
# rest=[]
match_list=[]

#유저별 스탯담을 데이터프레임
#mapName, matchType 추가!!
stats_df=pd.DataFrame()
stats_df_temp=pd.DataFrame()
stats_df_temp= stats_df_temp.append({
                                   "mapName":"",
                                   "matchType":"",
                                   "DBNOs":"",
                                   "assists":"",
                                   "boosts":"",
                                   "damageDealt":"",
                                   "deathType":"",
                                   "headshotKills":"",
                                   "heals":"",
                                   "killPlace":"",
                                   "killStreaks":"",
                                   "kills":"",
                                   "longestKill":"",
                                   "name":"",
                                   "playerId":"",
                                   "revives":"",
                                   "rideDistance":"",
                                   "roadKills":"",
                                   "swimDistance":"",
                                   "teamKills":"",
                                   "timeSurvived":"",
                                   "vehicleDestroys":"",
                                   "walkDistance":"",
                                   "weaponsAcquired":"",
                                   "winPlace":""
                                   },ignore_index=True)



# op.gg에서 랭커 500명 뽑아오기/ 상위3명과 나머지가 다른 구조로 담겨져있음.
#첫번째 포문은 상위3명 
#두번째 포문 나머지 497명
# ranker_url="https://pubg.op.gg/leaderboard/?platform=kakao&mode=competitive-tpp&queue_size=4"
# res=urllib.request.urlopen(ranker_url)
# soup=BeautifulSoup(res,"html.parser")

# for i in range(len(soup.find(class_="leader-board-top3").find_all(class_="leader-board-top3__item"))):
#     a=soup.find(class_="leader-board-top3").find_all(class_="leader-board-top3__item")[i].find('a').text
#     top_3.append(a)


# for i in range(1,498):
#     a=soup.find_all("tr")[i].find("a").get_text()
#     rest.append(a)

# ranker_list=top_3+rest

ranker_list=[]

#csv파일 불러와서 ranker_list로 가져오기
with open('KAKAO_Ranker_500_List.csv','r',encoding='utf-8') as f:
    rdr=csv.reader(f)
    for i, line in enumerate(rdr):
        if i==0:
            original_ranker_list=line

for i in range(125, 250):
    ranker_list.append(str(original_ranker_list[i]))        
    


#매치아이디 가져오기
#api호출 url과 랭커리스트의 아이디를 하나씩 결합하여 해당 아이디의 매치id를 가져와 매치리스트에 어펜드
#time.sleep을 건것은 api가 1분동안 호출할수있는 리밋을 걸어놨기 때문
#첫번째 포문: 랭커아이디를 결합하여 api를 호출
#두번째 포문: 매치아이디가 담겨져있는 구간으로가서 매치아이디를 매치리스트에 어펜드

for i in range(0, 125):
    print("지금수집하는 아이디"+str(ranker_list[i]))
    player_url_part1 = "https://api.pubg.com/shards/kakao/players?filter[playerNames]="
    player_url_part2=ranker_list[i]
    player_url=player_url_part1+player_url_part2
    header={
            "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiIzMjA2Mzc0MC1jYjQ1LTAxMzktMjRhZS02YmRmNDg5NWVmNWYiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI2NzU3MTcyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6IndpbnRlciJ9.tKO9nCSqIv4DmhThTRFo7sE2egsz5CIQEY9cyGUkTqI",
            "Accept": "application/vnd.api+json"
            } 
    r = requests.get(player_url, headers=header)
    player_json = r.json()
    time.sleep(7)
    try:
        for j in range(len(player_json['data'][0]['relationships']['matches']['data'])):
            match_list.append([player_json['data'][0]['relationships']['matches']['data'][j]['id'],i])
    except:
        pass

#첫번째 포문: 상위 10명만 돌리겠다!
#두번째 포문: 매치리스트를  결합하여 API애 유저별 경기스탯을 호출
#세번째 포문: 해당 아이디에 맞는 스탯을 선별하여 데이터프레임에 결합
#            TRY,EXCEPT 문을 활용하여 오류회피
# 20210720부로 이중포문 때에 mapName, matchType 가져오는 코드 수정
# Out:
# 지금수집하는 아이디Aots_
# 지금수집하는 아이디AFTV_O2shi
# 지금수집하는 아이디2cutUN
# 지금수집하는 아이디Tropium_marquis
# 지금수집하는 아이디Ami_1PYO
# 지금수집하는 아이디MND_SDT
# 지금수집하는 아이디MND_EOD
# 지금수집하는 아이디mongsil-0-
# 지금수집하는 아이디vkdnjfpdlswjfpem
# 지금수집하는 아이디40sex
# 지금수집하는 아이디HANYEOLSBR-_-
# 지금수집하는 아이디si1verstone
# 지금수집하는 아이디SSotonic
# 지금수집하는 아이디BORI_BIBIMBAP
# 지금수집하는 아이디SC1_MASTER_
# 지금수집하는 아이디SXX_KingJuGeun
# 지금수집하는 아이디hodukkagi
# 지금수집하는 아이디Asura_Defend
# 지금수집하는 아이디PSM_Angel
# 지금수집하는 아이디tRc-_-A
# 지금수집하는 아이디I_am_Jandi
# 지금수집하는 아이디2Man_Jikgu
# 지금수집하는 아이디KDT_Bongx2
# 지금수집하는 아이디WG_Zenod
# 지금수집하는 아이디AFTV_PSW
# 지금수집하는 아이디AFTVcaptain
# 지금수집하는 아이디lftyProfessional
# 지금수집하는 아이디KDT_Jxn
# 지금수집하는 아이디Hxuncute-3-
# 지금수집하는 아이디bananachocoshake
# 지금수집하는 아이디AFTV_Hwangco
# 지금수집하는 아이디iwantyourstaking
# 지금수집하는 아이디ssibbaseki
# 지금수집하는 아이디GRB_Hyun
# 지금수집하는 아이디baruming_-
# 지금수집하는 아이디rhdwndpdu
# 지금수집하는 아이디Assemble-Jin
# 지금수집하는 아이디S74777
# 지금수집하는 아이디Sexdox
# 지금수집하는 아이디gotica0
# 지금수집하는 아이디wudiyiliaobingya
# 지금수집하는 아이디BYUK_Carry
# 지금수집하는 아이디esirhc
# ...

# %%
type(match_list[-1][1])
# Out:
# int

# %%
for i in range(125, 250):
    for j in range(len(match_list)):
        matches_url_part1="https://api.pubg.com/shards/kakao/matches/"
        matches_url=matches_url_part1+match_list[j][0]
        header = { 
        "Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiIzMjA2Mzc0MC1jYjQ1LTAxMzktMjRhZS02YmRmNDg5NWVmNWYiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI2NzU3MTcyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6IndpbnRlciJ9.tKO9nCSqIv4DmhThTRFo7sE2egsz5CIQEY9cyGUkTqI",
        "Accept": "application/vnd.api+json"
        } 
        r = requests.get(matches_url, headers=header)
        matches_Goolbisoldier_json = r.json()
        stats_df_temp.iat[0,stats_df_temp.columns.get_loc("mapName")]=matches_Goolbisoldier_json["data"]["attributes"]["mapName"]
        stats_df_temp.iat[0,stats_df_temp.columns.get_loc("matchType")]=matches_Goolbisoldier_json["data"]["attributes"]["matchType"]

        for k in range(len(matches_Goolbisoldier_json["included"])):
            try:
                if matches_Goolbisoldier_json["included"][k]['attributes']['stats']['name']==ranker_list[i]:
                    print("걸렸다이놈:"+str(ranker_list[i]))
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("DBNOs")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["DBNOs"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("assists")]= matches_Goolbisoldier_json["included"][k]['attributes']['stats']["assists"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("boosts")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["boosts"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("damageDealt")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["damageDealt"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("deathType")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["deathType"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("headshotKills")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["headshotKills"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("heals")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["heals"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("killPlace")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["killPlace"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("killStreaks")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["killStreaks"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("kills")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["kills"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("longestKill")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["longestKill"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("name")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["name"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("playerId")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["playerId"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("revives")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["revives"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("rideDistance")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["rideDistance"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("roadKills")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["roadKills"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("swimDistance")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["swimDistance"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("teamKills")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["teamKills"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("timeSurvived")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["timeSurvived"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("vehicleDestroys")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["vehicleDestroys"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("walkDistance")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["walkDistance"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("weaponsAcquired")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["weaponsAcquired"]
                    stats_df_temp.iat[0,stats_df_temp.columns.get_loc("winPlace")]=matches_Goolbisoldier_json["included"][k]['attributes']['stats']["winPlace"]
                    stats_df=stats_df.append(stats_df_temp)

            except:
                pass

# %%
stats_df=stats_df.reset_index(drop=True)
stats_df.to_excel("ranker_top10_updated_Lizkon.xlsx",index=False)

# %%
match_list[0][0]
# Out:
# '1fac9904-4423-4f91-adaf-0825b8cd99fe'

# %%
stats_df=pd.DataFrame()
stats_df_temp=pd.DataFrame()
stats_df_temp= stats_df_temp.append({
                                   "mapName":"",
                                   "matchType":"",
                                   "DBNOs":"",
                                   "assists":"",
                                   "boosts":"",
                                   "damageDealt":"",
                                   "deathType":"",
                                   "headshotKills":"",
                                   "heals":"",
                                   "killPlace":"",
                                   "killStreaks":"",
                                   "kills":"",
                                   "longestKill":"",
                                   "name":"",
                                   "playerId":"",
                                   "revives":"",
                                   "rideDistance":"",
                                   "roadKills":"",
                                   "swimDistance":"",
                                   "teamKills":"",
                                   "timeSurvived":"",
                                   "vehicleDestroys":"",
                                   "walkDistance":"",
                                   "weaponsAcquired":"",
                                   "winPlace":""
                                   },ignore_index=True)

# %%
stats_df_temp
# Out:
#   DBNOs assists boosts damageDealt deathType headshotKills heals killPlace  \
# 0
#
#   killStreaks kills  ... revives rideDistance roadKills swimDistance  \
# 0                    ...
#
#   teamKills timeSurvived vehicleDestroys walkDistance weaponsAcquired winPlace
# 0
#
# [1 rows x 25 columns]
