# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("youtubepart3.csv")
data.head()
# Out:
#       video_id                                              title  \
# 0  RM5r6--CgD8  Cafe Vlog ♡ เปิดคาเฟ่1วัน ทำอะไรบ้าง? | MayyR ...
# 1  sFUPy4y7E4A             VLOG: ОТМЕЧАЕМ ДЕНЬ РОЖДЕНИЯ! 24.07.21
# 2  s7flUHafbHU                VLOG 181 HANGOVER LINDOL NAKAKAHILO
# 3  1qojGG62nRY  Vlog ep73 - กักตัวครบแล้ว, กินชาบู, น้องเลม่อน...
# 4  J5fCIfD2fEI                MRT Ride + Giveaway by Alex Gonzaga
#
#                                          description  \
# 0  Cafe Vlog วันนี้จะพาทุกคนไปคาเฟ่ ณ ประเทศขอนแก...
# 1  НАШ КАНАЛ SWEET HOME https://www.youtube.com/c...
# 2  👇🏼 free registration 👇🏼\nhttps://colorperya.co...
# 3  Contact : https://linktr.ee/Elitelab\n\nFlim :...
# 4  Comment nyo mga IG name or FB name niyo kapag ...
#
#                   channelId           channelTitle  subscriberCount  \
# 0  UCIXBJ0PYVIz0iHDB9-3-8JQ                 Mayy R        1670000.0
# 1  UCpm6vCgiehSKHtMFFS5ukiA          Katy LifeVlog        2660000.0
# ...

# %%
conda install -c conda-forge langdetect

# %%
from langdetect import detect_langs, detect

# %%
temp = data["description"][0]
temp
# Out:
# 'Cafe Vlog วันนี้จะพาทุกคนไปคาเฟ่ ณ ประเทศขอนแก่นกันค้าบบบบ มาดูกันว่า เปิดคาเฟ่1วัน ทำอะไรบ้าง? อยู่กันยาวๆไปเลยฮะ ตั้งแต่เปิดร้าน ทั้งทำน้ำ ทำขนมเค้ก ชิมกาแฟ บรรยากาศดีมาก นึกว่าอยู่เกาหลี5555 ไปดูกันเลยค่าาา\nFanpage : https://www.facebook.com/ImMayyrBlog\r\nIG : https://www.instagram.com/mayyr_/'

# %%
str(detect_langs(temp)[0])[:2]
# Out:
# 'th'

# %%
def trans_func(txt):
    temp = str(detect_langs(txt)[0])[:2]
    return temp

# %%
data.dropna(subset =["description"], inplace=True)

# %%
for i in range(0, len(data)):
    print(i)
    t = data.iat[i, data.columns.get_loc("description")]
    print(trans_func(t))
# Out:
# 0
# th
# 1
# bg
# 2
# en
# 3
# en
# 4
# tl
# 5
# fr
# 6
# tr
# 7
# tr
# 8
# en
# 9
# tr
# 10
# de
# 11
# en
# 12
# ar
# 13
# et
# 14
# tr
# 15
# bg
# 16
# en
# 17
# vi
# 18
# en
# 19
# cs
# 20
# tl
# 21
# en
# 22
# vi
# 23
# tr
# 24
# en
# 25
# tl
# 26
# tr
# 27
# fr
# 28
# en
# 29
# en
# 30
# pl
# 31
# de
# 32
# ro
# 33
# id
# 34
# en
# 35
# en
# 36
# es
# 37
# en
# 38
# de
# 39
# ja
# 40
# cs
# 41
# en
# 42
# en
# 43
# en
# 44
# en
# 45
# en
# 46
# en
# 47
# en
# 48
# en
# 49
# en
# 50
# tr
# 51
# pl
# 52
# en
# 53
# tl
# 54
# tr
# 55
# en
# 56
# fr
# 57
# pl
# 58
# id
# 59
# en
# 60
# el
# 61
# en
# 62
# en
# 63
# en
# 64
# en
# 65
# en
# 66
# tr
# 67
# en
# 68
# en
# 69
# en
# 70
# en
# 71
# en
# 72
# en
# 73
# pt
# 74
# pt
# 75
# en
# 76
# ko
# 77
# en
# 78
# en
# 79
# en
# 80
# en
# 81
# en
# 82
# en
# 83
# pt
# 84
# en
# 85
# en
# 86
# tr
# 87
# en
# 88
# en
# 89
# de
# 90
# en
# 91
# en
# 92
# en
# 93
# vi
# 94
# tl
# 95
# en
# 96
# en
# 97
# tl
# 98
# en
# 99
# en
# 100
# ...

# %%
detect_langs(data["description"][1094])
# Out:
# [en:0.9999964544035111]

# %%
data["Lang"] = data["description"].apply(lambda x:str(detect_langs(x)[0])[:2] )
# Out:
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# <ipython-input-25-367830a09d8a> in <module>
# ----> 1 data["Lang"] = data["description"].apply(lambda x:str(detect_langs(x)[0])[:2] )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-25-367830a09d8a> in <lambda>(x)
# ----> 1 data["Lang"] = data["description"].apply(lambda x:str(detect_langs(x)[0])[:2] )
#
# ~\anaconda3\lib\site-packages\langdetect\detector_factory.py in detect_langs(text)
#     135     detector = _factory.create()
# ...

# %%
pd.get_option("display.max_columns")
# Out:
# 20

# %%
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv("0802_gold_stats_for_er.csv")

# %%
data.head()
# Out:
#    DBNOs  assists  boosts  damageDealt deathType  duration gameMode  \
# 0      0        0       0    188.00002    logout      1807     solo
# 1      0        0       0      0.00000    logout      1807     solo
# 2      0        0       0      0.00000    logout      1807     solo
# 3      0        0       0    396.00000    logout      1807     solo
# 4      0        0       0      0.00000    logout      1807     solo
#
#    headshotKills  heals  killPlace  killStreaks  kills  longestKill  \
# 0              0      0          5            0      0          0.0
# 1              0      0         10            0      0          0.0
# 2              0      0         19            0      0          0.0
# 3              0      0         15            0      0          0.0
# 4              0      0         12            0      0          0.0
#
#       mapName matchType                              match_id       name  \
# ...

# %%
data["matchType"].value_counts()
# Out:
# official    116070
# training     18086
# Name: matchType, dtype: int64

# %%
data.loc[data["matchType"]=="official", "winPlace"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data["winPlace"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.describe()
# Out:
#                DBNOs   assists         boosts    damageDealt       duration  \
# count  134156.000000  134156.0  134156.000000  134156.000000  134156.000000
# mean        0.014081       0.0       1.788485     118.625450    1695.907786
# std         0.127077       0.0       2.759599     163.055186     235.412146
# min         0.000000       0.0       0.000000       0.000000     560.000000
# 25%         0.000000       0.0       0.000000       0.000000    1488.000000
# 50%         0.000000       0.0       0.000000      72.263323    1776.000000
# 75%         0.000000       0.0       3.000000     168.211205    1844.000000
# max         4.000000       0.0      23.000000    2114.520800    2551.000000
#
#        headshotKills          heals      killPlace    killStreaks  \
# count  134156.000000  134156.000000  134156.000000  134156.000000
# mean        0.183041       0.957959      45.649445       0.404179
# std         0.532071       2.311917      31.114059       0.533596
# ...

# %%
data["headshotKills"].value_counts()
# Out:
# 0     115843
# 1      13909
# 2       3137
# 3        882
# 4        266
# 5         79
# 6         25
# 7          7
# 8          6
# 10         1
# 11         1
# Name: headshotKills, dtype: int64

# %%
data.loc[(data["headshotKills"]==0)& (data["matchType"]=="official"),"winPlace"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.loc[(data["headshotKills"]>=1)& (data["matchType"]=="official"),"winPlace"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.loc[(data["headshotKills"]>=4)& (data["matchType"]=="official"),"winPlace"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.describe()
# Out:
#                DBNOs   assists         boosts    damageDealt       duration  \
# count  134156.000000  134156.0  134156.000000  134156.000000  134156.000000
# mean        0.014081       0.0       1.788485     118.625450    1695.907786
# std         0.127077       0.0       2.759599     163.055186     235.412146
# min         0.000000       0.0       0.000000       0.000000     560.000000
# 25%         0.000000       0.0       0.000000       0.000000    1488.000000
# 50%         0.000000       0.0       0.000000      72.263323    1776.000000
# 75%         0.000000       0.0       3.000000     168.211205    1844.000000
# max         4.000000       0.0      23.000000    2114.520800    2551.000000
#
#        headshotKills          heals      killPlace    killStreaks  \
# count  134156.000000  134156.000000  134156.000000  134156.000000
# mean        0.183041       0.957959      45.649445       0.404179
# std         0.532071       2.311917      31.114059       0.533596
# ...

# %%
data.loc[data["matchType"]=="official", :].describe()
# Out:
#                DBNOs   assists         boosts    damageDealt       duration  \
# count  116070.000000  116070.0  116070.000000  116070.000000  116070.000000
# mean        0.016275       0.0       2.054484     122.082703    1717.150056
# std         0.136488       0.0       2.866069     167.086761     211.236605
# min         0.000000       0.0       0.000000       0.000000    1210.000000
# 25%         0.000000       0.0       0.000000       0.000000    1504.000000
# 50%         0.000000       0.0       1.000000      75.000000    1776.000000
# 75%         0.000000       0.0       3.000000     170.117585    1854.000000
# max         4.000000       0.0      23.000000    2114.520800    2551.000000
#
#        headshotKills          heals      killPlace    killStreaks  \
# count  116070.000000  116070.000000  116070.000000  116070.000000
# mean        0.211562       1.102128      51.032687       0.467158
# std         0.566726       2.449147      29.993586       0.547421
# ...
